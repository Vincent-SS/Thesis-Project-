# %%
import pandas as pd
import numpy as np
import json
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import precision_score, recall_score, accuracy_score, mean_squared_error

# %% [markdown]
# # For each ticker (company), store all news into a dataframe

# %%
# Return one season's financial news dataframe
def season_dataframe(ticker, season):
    with open('./financial_news/'+ticker+str(season), 'r') as ticker_news:
        content  = ticker_news.read()
    records = json.loads(content)
    df = pd.DataFrame(records)
    return df

# %%
# Create dataframe for each ticker, storing its news
#ALL_TICKERS = ["$TSLA", "$NVDA", "$INTC", "$PFE", "$SPGI", "$LRCX", "$TMUS", "$ADSK", "$VRTX", "$TWTR", "$EBAY", "$CARR", "$VRSN", "$GRMN", "$ANET", "$AAL"]
#ALL_TICKERS = ["$TSLA", "$NVDA", "$INTC", "$PFE", "$SPGI", "$LRCX", "$TMUS", "$ADSK", "$VRTX", "$TWTR", "$EBAY", "$CARR", "$GRMN", "$ANET", "$AAL"]
ALL_TICKERS = ["$TSLA", "$INTC", "$PFE", "$SPGI", "$ADSK", "$VRTX", "$TWTR", "$EBAY", "$GRMN", "$AAL", "$ANET"]
ALL_TICKERS = ["$TSLA", "$INTC", "$PFE", "$SPGI", "$ADSK", "$VRTX", "$TWTR", "$EBAY", "$GRMN", "$AAL"]

df = []
for ticker in ALL_TICKERS:
  # Concatenate 8 seasons into one dataframe
  df_temp = pd.DataFrame()
  for i in range(1, 9):
      new_df = season_dataframe(ticker, i)
      df_temp = pd.concat([df_temp, new_df], ignore_index=True)
  df.append(df_temp)

# %% [markdown]
# Usage: df[0] will return $TSLA news from 2019-01-01 to 2020-12-31

# %% [markdown]
# Convert publishedDate to YYYY-MM-DD

# %%
# Helper function: for the date conversion
def remove_time(publish_date):
  return publish_date[0:10]

# %%
for each_df in df:
  each_df['publishedDate'] = each_df['publishedDate'].apply(remove_time)

# %% [markdown]
# Convert weekend to next Monday

# %%
# Helper function: Convert weekend to next Monday
def moveWeekend(publish_date):
  d = datetime.datetime(int(publish_date[0:4]), int(publish_date[5:7]), int(publish_date[8:10]))
  if (d.weekday() == 5):
    return str(d+datetime.timedelta(days=2))[0:10]
  elif (d.weekday() == 6):
    return str(d+datetime.timedelta(days=1))[0:10]
  else:
    return publish_date

# %%
for each_df in df:
  each_df['publishedDate'] = each_df['publishedDate'].apply(moveWeekend)

# %%
df[0]
# Out:
#      symbol publishedDate                                              title  \
# 0      TSLA    2020-12-31  Tesla to deliver China-made Model Y SUVs this ...
# 1      TSLA    2020-12-31  2020: Several Chinese Stocks Outperformed Thei...
# 2      TSLA    2020-12-31     EV Company News For The Month Of December 2020
# 3      TSLA    2020-12-31  Tesla, Volkswagen, Renault See Strong Share In...
# 4      TSLA    2020-12-31  Tech's top seven companies added $3.4 trillion...
# ...     ...           ...                                                ...
# 5817   TSLA    2019-01-18         Behind Elon Musk's Hiring and Firing Spree
# 5818   TSLA    2019-01-17  Tesla to cut full time workforce by roughly 7%...
# 5819   TSLA    2019-01-07  Cramer: New Tesla factory in Shanghai will wor...
# 5820   TSLA    2019-01-03  Tesla stock drops over missed delivery estimat...
# 5821   TSLA    2019-01-01  Tesla misses Wall Street estimates with 90,700...
#
#                                                   image                  site  \
# 0     https://cdn.snapi.dev/images/v1/5/m/m02d202101...               Reuters
# 1     https://cdn.snapi.dev/images/v1/f/j/catalog-ma...         Seeking Alpha
# 2     https://cdn.snapi.dev/images/v1/l/r/sssik22-c5...         Seeking Alpha
# 3       https://cdn.snapi.dev/images/v1/v/x/s3xy-14.jpg              Benzinga
# 4     https://cdn.snapi.dev/images/v1/s/t/stocks23-1...                  CNBC
# ...                                                 ...                   ...
# 5817  https://cdn.snapi.dev/images/v1/v/i/viwtqd6wkp...  Bloomberg Technology
# 5818  https://cdn.snapi.dev/images/v1/t/8/t8cnbozbfx...       CNBC Television
# 5819  https://cdn.snapi.dev/images/v1/w/g/wgegqwogy8...       CNBC Television
# 5820  https://cdn.snapi.dev/images/v1/b/e/bebskx74-2...          Fox Business
# 5821  https://cdn.snapi.dev/images/v1/p/l/plxkuv4cmd...       CNBC Television
#
#                                                    text  \
# 0     Tesla Inc said on Friday it has started sellin...
# 1     2020: Several Chinese Stocks Outperformed Thei...
# 2     Global electric car sales records for November...
# 3     The European market continues to see strong ad...
# 4     Big Tech got much bigger in 2020, and Tesla jo...
# ...                                                 ...
# 5817  Elon Musk is cutting Tesla Inc.'s workforce by...
# 5818  The Wall Street Journal is reporting that Tesl...
# 5819  CNBC's Jim Cramer discusses his take on the la...
# 5820  “Bulls & Bears” panel discusses how Tesla shar...
# 5821  CNBC's Phil LeBeau reports on Tesla's deliveri...
#
#                                                     url
# 0     https://www.reuters.com/article/us-tesla-china...
# 1     https://seekingalpha.com/article/4396892-2020-...
# 2     https://seekingalpha.com/article/4396884-ev-co...
# 3     https://www.benzinga.com/news/20/12/18973120/t...
# 4     https://www.cnbc.com/2020/12/31/techs-top-seve...
# ...                                                 ...
# 5817        https://www.youtube.com/watch?v=ViwTqD6WKpA
# 5818        https://www.youtube.com/watch?v=t8CNBOZBFXc
# 5819        https://www.youtube.com/watch?v=WGEgQWogY8E
# 5820        https://www.youtube.com/watch?v=Bebskx74-2Y
# 5821        https://www.youtube.com/watch?v=pLxkuV4cmdI
#
# [5822 rows x 7 columns]

# %% [markdown]
# # Plain text approach bag_of_words

# %%
for index, each_df in enumerate(df):
  df[index] = each_df[['symbol', 'publishedDate', 'title', 'text']]

# %%
df[0]
# Out:
#      symbol publishedDate                                              title  \
# 0      TSLA    2020-12-31  Tesla to deliver China-made Model Y SUVs this ...
# 1      TSLA    2020-12-31  2020: Several Chinese Stocks Outperformed Thei...
# 2      TSLA    2020-12-31     EV Company News For The Month Of December 2020
# 3      TSLA    2020-12-31  Tesla, Volkswagen, Renault See Strong Share In...
# 4      TSLA    2020-12-31  Tech's top seven companies added $3.4 trillion...
# ...     ...           ...                                                ...
# 5817   TSLA    2019-01-18         Behind Elon Musk's Hiring and Firing Spree
# 5818   TSLA    2019-01-17  Tesla to cut full time workforce by roughly 7%...
# 5819   TSLA    2019-01-07  Cramer: New Tesla factory in Shanghai will wor...
# 5820   TSLA    2019-01-03  Tesla stock drops over missed delivery estimat...
# 5821   TSLA    2019-01-01  Tesla misses Wall Street estimates with 90,700...
#
#                                                    text
# 0     Tesla Inc said on Friday it has started sellin...
# 1     2020: Several Chinese Stocks Outperformed Thei...
# 2     Global electric car sales records for November...
# 3     The European market continues to see strong ad...
# 4     Big Tech got much bigger in 2020, and Tesla jo...
# ...                                                 ...
# 5817  Elon Musk is cutting Tesla Inc.'s workforce by...
# 5818  The Wall Street Journal is reporting that Tesl...
# 5819  CNBC's Jim Cramer discusses his take on the la...
# 5820  “Bulls & Bears” panel discusses how Tesla shar...
# 5821  CNBC's Phil LeBeau reports on Tesla's deliveri...
#
# [5822 rows x 4 columns]

# %%
df
# Out:
# [     symbol publishedDate                                              title  \
#  0      TSLA    2020-12-31  Tesla to deliver China-made Model Y SUVs this ...
#  1      TSLA    2020-12-31  2020: Several Chinese Stocks Outperformed Thei...
#  2      TSLA    2020-12-31     EV Company News For The Month Of December 2020
#  3      TSLA    2020-12-31  Tesla, Volkswagen, Renault See Strong Share In...
#  4      TSLA    2020-12-31  Tech's top seven companies added $3.4 trillion...
#  ...     ...           ...                                                ...
#  5817   TSLA    2019-01-18         Behind Elon Musk's Hiring and Firing Spree
#  5818   TSLA    2019-01-17  Tesla to cut full time workforce by roughly 7%...
#  5819   TSLA    2019-01-07  Cramer: New Tesla factory in Shanghai will wor...
#  5820   TSLA    2019-01-03  Tesla stock drops over missed delivery estimat...
#  5821   TSLA    2019-01-01  Tesla misses Wall Street estimates with 90,700...
#
#                                                     text
#  0     Tesla Inc said on Friday it has started sellin...
#  1     2020: Several Chinese Stocks Outperformed Thei...
#  2     Global electric car sales records for November...
#  3     The European market continues to see strong ad...
#  4     Big Tech got much bigger in 2020, and Tesla jo...
#  ...                                                 ...
#  5817  Elon Musk is cutting Tesla Inc.'s workforce by...
#  5818  The Wall Street Journal is reporting that Tesl...
#  5819  CNBC's Jim Cramer discusses his take on the la...
#  5820  “Bulls & Bears” panel discusses how Tesla shar...
#  5821  CNBC's Phil LeBeau reports on Tesla's deliveri...
#
#  [5822 rows x 4 columns],
#       symbol publishedDate                                              title  \
#  0      INTC    2020-12-31         Intel: A Troubled 'New' Modern Corporation
#  1      INTC    2020-12-31             Activists Hunted Big Game in Late 2020
#  2      INTC    2020-12-31  Top 10 Undervalued High-Yield Income Stocks Fo...
#  3      INTC    2020-12-31  Intel needs to do a better job reassuring its ...
#  4      INTC    2020-12-31  3 Cybersecurity Stocks That May Give Double-Di...
#  ...     ...           ...                                                ...
#  1586   INTC    2019-01-09             How Intel is innovating in 2019 at CES
#  1587   INTC    2019-01-08  How Intel Intends to Launch 5G, With a Surpris...
#  1588   INTC    2019-01-07                  Intel CES 2019 event in 9 minutes
#  1589   INTC    2019-01-03                       Final Trade: XRT, CBS & more
#  1590   INTC    2019-01-01               Chip sector decline expected in 2019
#
#                                                     text
#  0     In the face of many new stock market highs and...
#  1     The number of activist campaigns was lacking, ...
#  2     2021 could be a year in which value stocks out...
#  3     CNBC's "Squawk Alley" team discusses Third Poi...
#  4     Here we discuss three stocks -- QLYS, FTNT, FE...
#  ...                                                 ...
#  1586                                 INTC´s news at CES
#  1587                         CES 2019´s technology news
#  1588  Intel is at CES 2019, showing its rivals that ...
#  1589  The "Fast Money" traders share their final tra...
#  1590  Romit Shah, managing director and senior analy...
#
#  [1591 rows x 4 columns],
#       symbol publishedDate                                              title  \
#  0       PFE    2020-12-31  Pfizer Criticizes Sudden Change in Coronavirus...
#  1       PFE    2020-12-31  Why Pfizer is the Cheapest Coronavirus Vaccine...
#  2       PFE    2020-12-31             Top ETF Stories of Fourth-Quarter 2020
#  3       PFE    2020-12-31   5 Big ETF Stories of 2020 Worth Watching in 2021
#  4       PFE    2020-12-31  U.K. health service pushes back interval for d...
#  ...     ...           ...                                                ...
#  1287    PFE    2019-01-28  Stocks Mixed: Apple Earnings Due, Pfizer Repor...
#  1288    PFE    2019-01-24                          Earnings Thirteen: 4 buys
#  1289    PFE    2019-01-17  Bulls bet on this biopharma company. Plus, the...
#  1290    PFE    2019-01-02  Is now a good time to buy tech? Is 3M poised t...
#  1291    PFE    2019-01-01                  Final Trades: FDX, PFE, & Bitcoin
#
#                                                     text
#  0     The company sounded alarm bells about the wide...
#  1     PFE stock does not include any value to the Pf...
#  2     The year 2020 as a whole could easily be attri...
#  3     We discuss some of the events that dominated t...
#  4     The U.K. National Health Service has pushed ba...
#  ...                                                 ...
#  1287  Investor's Business Daily's MARKET UPDATE, wit...
#  1288  The "Fast Money" traders give you 4 buys ahead...
#  1289  "Halftime Report" traders Jon and Pete Najaria...
#  1290  The "Halftime Report" traders answer viewer qu...
#  1291  The “Fast Money” traders discuss how to trade ...
#
#  [1292 rows x 4 columns],
#      symbol publishedDate                                              title  \
#  0     SPGI    2020-12-29  S&P Global (SPGI) Stock Rises 16.5% Year to Da...
#  1     SPGI    2020-12-21  Lifshitz Law Firm, P.C. Announces Investigatio...
#  2     SPGI    2020-12-18  S&P Global Platts: The worst is still yet to c...
#  3     SPGI    2020-12-17  S&P Global (SPGI) And IHS Markit (INFO) Reveal...
#  4     SPGI    2020-12-16  S&P Global and IHS Markit Announce Divisional ...
#  ..     ...           ...                                                ...
#  170   SPGI    2019-04-03  S&P Global's David Blitzer's Near 40-Year Term...
#  171   SPGI    2019-04-02        S&P Global: Checks All Of The Boxes But One
#  172   SPGI    2019-03-11  Why Is S&P Global (SPGI) Up 0.7% Since Last Ea...
#  173   SPGI    2019-02-12  S&P Global Platts: It's not the quantity, but ...
#  174   SPGI    2019-02-11    S&P Global CEO: Narrowing Our Focus - Mad Money
#
#                                                    text
#  0    Consecutive better-than-expected top- and bott...
#  1    NEW YORK, Dec. 20, 2020 /PRNewswire/ -- IHS Ma...
#  2    Chris Midgley of S&P Global Platts says the re...
#  3    Recently, S&P Global (NYSE: SPGI) and IHS Mark...
#  4    NEW YORK and LONDON, Dec. 16, 2020 /PRNewswire...
#  ..                                                 ...
#  170  Blitzer joined S&P Global's (SPGI) index commi...
#  171  The company operates at the heart of the globa...
#  172  S&P Global (SPGI) reported earnings 30 days ag...
#  173  Eklavya Gupte of S and P Global Platts discuss...
#  174  S&P Global’s mixed earnings results may have s...
#
#  [175 rows x 4 columns],
#      symbol publishedDate                                              title  \
#  0     ADSK    2020-12-24  Why Is Autodesk (ADSK) Up 10.7% Since Last Ear...
#  1     ADSK    2020-12-15  The Smartest People On Wall Street Are Buying ...
#  2     ADSK    2020-12-11             Is Autodesk a Stock for the Long Haul?
#  3     ADSK    2020-12-09  The Ratings Game: These software stocks could ...
#  4     ADSK    2020-12-01  Autodesk Is Firing On All Cylinders, But Its M...
#  ..     ...           ...                                                ...
#  308   ADSK    2019-04-01  Why Is Autodesk Down 4.4% Since Last Earnings ...
#  309   ADSK    2019-03-29  Autodesk Analysts Talk Growth Drivers After In...
#  310   ADSK    2019-03-11    Why Autodesk Stock Popped Nearly 11% Last Month
#  311   ADSK    2019-02-28  AutoDesk CEO: We don't believe digitized desig...
#  312   ADSK    2019-02-11                      MARKET UPDATE: Autodesk, Inc.
#
#                                                    text
#  0    Autodesk (ADSK) reported earnings 30 days ago....
#  1    All three stocks have had a strong year, and b...
#  2    Why this software giant should remain the indu...
#  3    An improving economy once widespread COVID-19 ...
#  4    Last week, we saw Dell Technologies Inc (NYSE:...
#  ..                                                 ...
#  308  Autodesk reported earnings 30 days ago. What's...
#  309  Applications software vendor Autodesk, Inc. he...
#  310  Positive notes from two analysts likely pushed...
#  311  Autodesk CEO Andrew Anagnost joins "Squawk All...
#  312  Investor's Business Daily's MARKET UPDATE with...
#
#  [313 rows x 4 columns],
#      symbol publishedDate                                              title  \
#  0     VRTX    2020-12-28       The 3 Best Healthcare Stocks to Buy for 2021
#  1     VRTX    2020-12-28  3 Surefire Stocks to Buy With Your $600 Stimul...
#  2     VRTX    2020-12-24  Vertex Pharmaceuticals (VRTX) Stock Sinks As M...
#  3     VRTX    2020-12-24                   Where to Invest $5,000 Right Now
#  4     VRTX    2020-12-24                         The 3 Best Stocks for 2021
#  ..     ...           ...                                                ...
#  463   VRTX    2019-03-19  Biotech Giant Tumbles On Downgrade Amid Payer ...
#  464   VRTX    2019-03-11  Why Vertex's Dilemma Makes It the Best Biotech...
#  465   VRTX    2019-03-11     Stocks This Week: Short Vertex Pharmaceuticals
#  466   VRTX    2019-02-05  MARKET UPDATE: Vertex Pharmaceuticals Incorpor...
#  467   VRTX    2019-01-09  Indexes Open Lower; Retailers Slump On Holiday...
#
#                                                    text
#  0    All three could be huge winners in the new yea...
#  1    Making money is easy when you're invested in h...
#  2    Vertex Pharmaceuticals (VRTX) closed at $234.4...
#  3    If you're worried another market crash is immi...
#  4    A beaten-down biotech, a streaming star, and a...
#  ..                                                 ...
#  463  Vertex Pharmaceuticals stock slipped below its...
#  464  Excellent clinical trial results are giving Ve...
#  465  Vertex Pharmaceuticals is picked up by the cyc...
#  466  Investor's Business Daily's MARKET UPDATE with...
#  467          Alissa Coram & Ken Shreve´s market update
#
#  [468 rows x 4 columns],
#       symbol publishedDate                                              title  \
#  0      TWTR    2020-12-29           Does Twitter Have a User Growth Problem?
#  1      TWTR    2020-12-29  The source behind the New York Post's dubious ...
#  2      TWTR    2020-12-29  Apple, Boeing, Nike, Airbnb, DoorDash and More...
#  3      TWTR    2020-12-28  Twitter Sued By Owner Of Repair Shop Who Claim...
#  4      TWTR    2020-12-28                         Twitter: Periscope Debacle
#  ...     ...           ...                                                ...
#  1780   TWTR    2019-01-24  How investors should handle stocks such as Tes...
#  1781   TWTR    2019-01-22  Tech sector's performance in the market. - Ama...
#  1782   TWTR    2019-01-09                    Twitter soars on double upgrade
#  1783   TWTR    2019-01-08  Facebook, Twitter consult with conservative gr...
#  1784   TWTR    2019-01-07  'It's time to shine' for 2019 tech IPOs, says ...
#
#                                                     text
#  0     Near-term user growth may be disappointing, bu...
#  1     The laptop repairman at the center of the New ...
#  2     This has been the year of the virus, and like ...
#  3     The owner of a Mac repair shop filed a $500 mi...
#  4     Twitter plans to shut down Periscope at the en...
#  ...                                                 ...
#  1780  Tesla, Facebook, Twitter and Netflix - Citron ...
#  1781  Aaron Kessler, senior internet analyst at Raym...
#  1782  The "Halftime Report" traders debate Bank of A...
#  1783  “Bulls & Bears” panel on how Facebook and Twit...
#  1784  Mark Kelley, executive director and internet a...
#
#  [1785 rows x 4 columns],
#      symbol publishedDate                                              title  \
#  0     EBAY    2020-12-30               What Happened to eBay Stock in 2020?
#  1     EBAY    2020-12-29  EBay (EBAY) Gains As Market Dips: What You Sho...
#  2     EBAY    2020-12-25  eBay shares are up 38% YTD. Here's the next ta...
#  3     EBAY    2020-12-22  EBay (EBAY) Gains As Market Dips: What You Sho...
#  4     EBAY    2020-12-22                           eBay Is A Deep Value Buy
#  ..     ...           ...                                                ...
#  792   EBAY    2019-01-29                    Final Trades: AMGN, EBAY & More
#  793   EBAY    2019-01-28       Who's Got the Best Earnings Chart This Week?
#  794   EBAY    2019-01-22  Tech sector's performance in the market. - Ama...
#  795   EBAY    2019-01-21       Elliott Management takes $1.4B stake in eBay
#  796   EBAY    2019-01-14  These are Oakmark's Bill Nygren's top stock picks
#
#                                                    text
#  0    Shareholders trounced the market during this v...
#  1    EBay (EBAY) closed the most recent trading day...
#  2    eBay (NASDAQ: EBAY) shares have advanced from ...
#  3    EBay (EBAY) closed at $51.62 in the latest tra...
#  4    eBay is priced as if it struggles to survive i...
#  ..                                                 ...
#  792  The "Fast Money" traders share their final tra...
#  793  Love them or hate them, these five companies w...
#  794  Aaron Kessler, senior internet analyst at Raym...
#  795  "Squawk on the Street" discusses what Elliott ...
#  796  Bill Nygren, The Oakmark Investor Fund portfol...
#
#  [797 rows x 4 columns],
#      symbol publishedDate                                              title  \
#  0     GRMN    2020-12-23  V&M Top Growth And Dividend MDA Breakouts: 202...
#  1     GRMN    2020-12-23  Final Trades: Garmin, Penn National, Alibaba &...
#  2     GRMN    2020-12-22  3 Stocks with Strong Dividends to Buy for Grow...
#  3     GRMN    2020-12-22  Garmin (GRMN) GFC 500 Autopilot Certification ...
#  4     GRMN    2020-12-22  Got $1,000? Here's Why You Should Buy Shares o...
#  ..     ...           ...                                                ...
#  173   GRMN    2020-04-22  Garmin (GRMN) Earnings Expected to Grow: Shoul...
#  174   GRMN    2020-04-22  Garmin (GRMN) Earnings Expected to Grow: Shoul...
#  175   GRMN    2020-04-22  Want an Apple Watch but... don't? Check out th...
#  176   GRMN    2020-04-22  Amphenol (APH) Q1 Earnings Lag Estimates, Reve...
#  177   GRMN    2020-04-22  Amphenol (APH) Q1 Earnings Lag Estimates, Reve...
#
#                                                    text
#  0    The 2020 Growth & Dividend MDA Portfolios are ...
#  1    The "Halftime Report" traders give their top p...
#  2    Investors might want to consider adding stocks...
#  3    Garmin (GRMN) receives Supplemental Type Certi...
#  4    These established businesses are well-position...
#  ..                                                 ...
#  173  Garmin (GRMN) doesn't possess the right combin...
#  174  Garmin (GRMN) doesn't possess the right combin...
#  175  The Apple Watch isn't the only smartwatch in t...
#  176  Amphenol's (APH) Q1 results reflect production...
#  177  Amphenol's (APH) Q1 results reflect production...
#
#  [178 rows x 4 columns],
#       symbol publishedDate                                              title  \
#  0       AAL    2020-12-31  Final Trades: Goldman Sachs, American Airlines...
#  1       AAL    2020-12-31  Jon Najarian reveals the top picks in his 2021...
#  2       AAL    2020-12-31  Airlines Need More Bailouts to Avoid High Bank...
#  3       AAL    2020-12-31                         5 Stocks to Sell Right Now
#  4       AAL    2020-12-30  Are Airline Stocks a Buy Following the Latest ...
#  ...     ...           ...                                                ...
#  1496    AAL    2019-01-23  Airline Stocks & TXN Report Earnings, Jobless ...
#  1497    AAL    2019-01-21  Investors worry the airline industry may not t...
#  1498    AAL    2019-01-14             ETF Spotlight: Airlines under pressure
#  1499    AAL    2019-01-09              American Airlines drags down airlines
#  1500    AAL    2019-01-02   Airline sell-off an 'overreaction': CFRA Analyst
#
#                                                     text
#  0     The "Halftime Report" traders give their top p...
#  1     CNBC "Halftime Report" trader Jon Najarian, co...
#  2     On Dec. 27, the U.S. government's latest relie...
#  3     Today's the final day for tax-loss harvesting ...
#  4     Many investors have been keeping a close eye o...
#  ...                                                 ...
#  1496  Ryan McQueeney recaps earnings results from Te...
#  1497  “Bulls & Bears” panel on whether investors sho...
#  1498  CNBC's Dom Chu report on the decline of the ai...
#  1499  CNBC's Phil Lebeau reports on American Airline...
#  1500  CNBC's Phil LeBeau breaks down why airlines ar...
#
#  [1501 rows x 4 columns]]

# %%
polarity = df
polarity[0]
# Out:
#      symbol publishedDate                                              title  \
# 0      TSLA    2020-12-31  Tesla to deliver China-made Model Y SUVs this ...
# 1      TSLA    2020-12-31  2020: Several Chinese Stocks Outperformed Thei...
# 2      TSLA    2020-12-31     EV Company News For The Month Of December 2020
# 3      TSLA    2020-12-31  Tesla, Volkswagen, Renault See Strong Share In...
# 4      TSLA    2020-12-31  Tech's top seven companies added $3.4 trillion...
# ...     ...           ...                                                ...
# 5817   TSLA    2019-01-18         Behind Elon Musk's Hiring and Firing Spree
# 5818   TSLA    2019-01-17  Tesla to cut full time workforce by roughly 7%...
# 5819   TSLA    2019-01-07  Cramer: New Tesla factory in Shanghai will wor...
# 5820   TSLA    2019-01-03  Tesla stock drops over missed delivery estimat...
# 5821   TSLA    2019-01-01  Tesla misses Wall Street estimates with 90,700...
#
#                                                    text
# 0     Tesla Inc said on Friday it has started sellin...
# 1     2020: Several Chinese Stocks Outperformed Thei...
# 2     Global electric car sales records for November...
# 3     The European market continues to see strong ad...
# 4     Big Tech got much bigger in 2020, and Tesla jo...
# ...                                                 ...
# 5817  Elon Musk is cutting Tesla Inc.'s workforce by...
# 5818  The Wall Street Journal is reporting that Tesl...
# 5819  CNBC's Jim Cramer discusses his take on the la...
# 5820  “Bulls & Bears” panel discusses how Tesla shar...
# 5821  CNBC's Phil LeBeau reports on Tesla's deliveri...
#
# [5822 rows x 4 columns]

# %%
# Merge title, text based on publishedDate
for index, each_polarity in enumerate(polarity):
  symbol = each_polarity['symbol'][0]
  title = each_polarity.groupby(['publishedDate'])['title'].apply(','.join).reset_index()
  text = each_polarity.groupby(['publishedDate'])['text'].apply(','.join).reset_index()
  total = pd.merge(title, text, on="publishedDate")
  polarity[index] = total
  polarity[index]['symbol'] = symbol

# %%
polarity[0]
# Out:
#     publishedDate                                              title  \
# 0      2019-01-01  Tesla misses Wall Street estimates with 90,700...
# 1      2019-01-03  Tesla stock drops over missed delivery estimat...
# 2      2019-01-07  Cramer: New Tesla factory in Shanghai will wor...
# 3      2019-01-17  Tesla to cut full time workforce by roughly 7%...
# 4      2019-01-18         Behind Elon Musk's Hiring and Firing Spree
# ..            ...                                                ...
# 429    2020-12-25  TSLA Stock Price: $788 Target By JMP Securitie...
# 430    2020-12-28  Tesla To Enter India Early Next Year, Transpor...
# 431    2020-12-29  Tesla Stock Price: Target Increase From $300 T...
# 432    2020-12-30  Move Over, Warren Buffett: This Is the Star In...
# 433    2020-12-31  Tesla to deliver China-made Model Y SUVs this ...
#
#                                                   text symbol
# 0    CNBC's Phil LeBeau reports on Tesla's deliveri...   TSLA
# 1    “Bulls & Bears” panel discusses how Tesla shar...   TSLA
# 2    CNBC's Jim Cramer discusses his take on the la...   TSLA
# 3    The Wall Street Journal is reporting that Tesl...   TSLA
# 4    Elon Musk is cutting Tesla Inc.'s workforce by...   TSLA
# ..                                                 ...    ...
# 429  The stock price of Tesla Inc (NASDAQ: TSLA) ha...   TSLA
# 430  Tesla Inc (NASDAQ: TSLA) is set to debut in In...   TSLA
# 431  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...   TSLA
# 432  Berkshire's best days seem to be behind it, bu...   TSLA
# 433  Tesla Inc said on Friday it has started sellin...   TSLA
#
# [434 rows x 4 columns]

# %%
# Merge everyday's closing price with polarity dataframe
index = 0
for ticker in ALL_TICKERS:
  data = pd.read_csv("./stock_price/compare_previous_day/"+ticker[1:]+".csv")
  data = data[['Date', 'Close']]
  data['publishedDate'] = data['Date']
  data = data[['publishedDate', 'Close']]
  polarity[index] = pd.merge(data, polarity[index], on = 'publishedDate', how = 'left').fillna(0)
  polarity[index]['symbol'] = ALL_TICKERS[index][1:]
  index+=1

# %%
polarity[0]
# Out:
#     publishedDate       Close  \
# 0      2018-12-31   66.559998
# 1      2019-01-02   62.023998
# 2      2019-01-03   60.071999
# 3      2019-01-04   63.537998
# 4      2019-01-07   66.991997
# ..            ...         ...
# 501    2020-12-24  661.770020
# 502    2020-12-28  663.690002
# 503    2020-12-29  665.989990
# 504    2020-12-30  694.780029
# 505    2020-12-31  705.669983
#
#                                                  title  \
# 0                                                    0
# 1                                                    0
# 2    Tesla stock drops over missed delivery estimat...
# 3                                                    0
# 4    Cramer: New Tesla factory in Shanghai will wor...
# ..                                                 ...
# 501  Top ETF Stories of 2020 & Picks for 2021,Apple...
# 502  Tesla To Enter India Early Next Year, Transpor...
# 503  Tesla Stock Price: Target Increase From $300 T...
# 504  Move Over, Warren Buffett: This Is the Star In...
# 505  Tesla to deliver China-made Model Y SUVs this ...
#
#                                                   text symbol
# 0                                                    0   TSLA
# 1                                                    0   TSLA
# 2    “Bulls & Bears” panel discusses how Tesla shar...   TSLA
# 3                                                    0   TSLA
# 4    CNBC's Jim Cramer discusses his take on the la...   TSLA
# ..                                                 ...    ...
# 501  We discuss the 2020 trends and outlook for 202...   TSLA
# 502  Tesla Inc (NASDAQ: TSLA) is set to debut in In...   TSLA
# 503  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...   TSLA
# 504  Berkshire's best days seem to be behind it, bu...   TSLA
# 505  Tesla Inc said on Friday it has started sellin...   TSLA
#
# [506 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
for each_polarity in polarity:
  close = each_polarity['Close']
  scaler = MinMaxScaler(feature_range=(0,1))
  close = scaler.fit_transform(np.array(close).reshape(-1,1))
  each_polarity['today_scaler'] = close

# %%
for each_polarity in polarity:
  data = pd.read_csv("./stock_price/compare_previous_day/"+each_polarity.symbol.loc[0]+".csv")
  each_polarity['indicator'] = data['indicator']

# %%
polarity[0]
# Out:
#     publishedDate       Close  \
# 0      2018-12-31   66.559998
# 1      2019-01-02   62.023998
# 2      2019-01-03   60.071999
# 3      2019-01-04   63.537998
# 4      2019-01-07   66.991997
# ..            ...         ...
# 501    2020-12-24  661.770020
# 502    2020-12-28  663.690002
# 503    2020-12-29  665.989990
# 504    2020-12-30  694.780029
# 505    2020-12-31  705.669983
#
#                                                  title  \
# 0                                                    0
# 1                                                    0
# 2    Tesla stock drops over missed delivery estimat...
# 3                                                    0
# 4    Cramer: New Tesla factory in Shanghai will wor...
# ..                                                 ...
# 501  Top ETF Stories of 2020 & Picks for 2021,Apple...
# 502  Tesla To Enter India Early Next Year, Transpor...
# 503  Tesla Stock Price: Target Increase From $300 T...
# 504  Move Over, Warren Buffett: This Is the Star In...
# 505  Tesla to deliver China-made Model Y SUVs this ...
#
#                                                   text symbol  today_scaler  \
# 0                                                    0   TSLA      0.045928
# 1                                                    0   TSLA      0.039157
# 2    “Bulls & Bears” panel discusses how Tesla shar...   TSLA      0.036243
# 3                                                    0   TSLA      0.041417
# 4    CNBC's Jim Cramer discusses his take on the la...   TSLA      0.046573
# ..                                                 ...    ...           ...
# 501  We discuss the 2020 trends and outlook for 202...   TSLA      0.934466
# 502  Tesla Inc (NASDAQ: TSLA) is set to debut in In...   TSLA      0.937332
# 503  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...   TSLA      0.940765
# 504  Berkshire's best days seem to be behind it, bu...   TSLA      0.983743
# 505  Tesla Inc said on Friday it has started sellin...   TSLA      1.000000
#
#      indicator
# 0          0.0
# 1          0.0
# 2          0.0
# 3          1.0
# 4          1.0
# ..         ...
# 501        1.0
# 502        1.0
# 503        1.0
# 504        1.0
# 505        1.0
#
# [506 rows x 7 columns]

# %% [markdown]
# # Apply bag_of_words and TFIDF

# %%
import re
a = "Cramer: New Tesla factory i"
a = re.sub("[^a-zA-Z]+", " ", a)
print(a)
# Out:
# Cramer New Tesla factory i

# %%
# Remove punctuations
def removePunc(st):
  s = str(st)
  s = re.sub("[^a-zA-Z]+", " ", s)
  return s

# %%
for each_polarity in polarity:
  each_polarity['title'] = each_polarity['title'].apply(removePunc)
  each_polarity['text'] = each_polarity['text'].apply(removePunc)
  #print(each_polarity['title_p'])

# %%
polarity[1]
# Out:
#     publishedDate      Close  \
# 0      2018-12-31  46.930000
# 1      2019-01-02  47.080002
# 2      2019-01-03  44.490002
# 3      2019-01-04  47.220001
# 4      2019-01-07  47.439999
# ..            ...        ...
# 501    2020-12-24  47.070000
# 502    2020-12-28  47.070000
# 503    2020-12-29  49.389999
# 504    2020-12-30  48.750000
# 505    2020-12-31  49.820000
#
#                                                  title  \
# 0
# 1
# 2                             final trade xrt cbs more
# 3
# 4                           intel ces event in minutes
# ..                                                 ...
# 501
# 502  barron s post christmas picks and pans alibaba...
# 503  noted activist investor calls on intel to expl...
# 504  intel intc stock sinks as market gains what yo...
# 505  intel a troubled new modern corporation activi...
#
#                                                   text symbol  today_scaler  \
# 0                                                        INTC      0.138745
# 1                                                        INTC      0.144742
# 2                             final trade xrt cbs more   INTC      0.041184
# 3                                                        INTC      0.150340
# 4                           intel ces event in minutes   INTC      0.159136
# ..                                                 ...    ...           ...
# 501                                                      INTC      0.144342
# 502  barron s post christmas picks and pans alibaba...   INTC      0.144342
# 503  noted activist investor calls on intel to expl...   INTC      0.237105
# 504  intel intc stock sinks as market gains what yo...   INTC      0.211515
# 505  intel a troubled new modern corporation activi...   INTC      0.254298
#
#      indicator  scaler-1  scaler-2  scaler-3  scaler-4  scaler-5  scaler-6
# 0          0.0  0.138745  0.138745  0.138745  0.138745  0.138745  0.138745
# 1          1.0  0.138745  0.138745  0.138745  0.138745  0.138745  0.138745
# 2          0.0  0.144742  0.138745  0.144742  0.144742  0.144742  0.144742
# 3          1.0  0.041184  0.144742  0.138745  0.041184  0.041184  0.041184
# 4          1.0  0.150340  0.041184  0.144742  0.138745  0.150340  0.150340
# ..         ...       ...       ...       ...       ...       ...       ...
# 501        1.0  0.124350  0.108357  0.115954  0.159936  0.287485  0.306277
# 502        0.0  0.144342  0.124350  0.108357  0.115954  0.159936  0.287485
# 503        1.0  0.144342  0.144342  0.124350  0.108357  0.115954  0.159936
# 504        0.0  0.237105  0.144342  0.144342  0.124350  0.108357  0.115954
# 505        1.0  0.211515  0.237105  0.144342  0.144342  0.124350  0.108357
#
# [506 rows x 13 columns]

# %%
# Convert to lower cases
for each_polarity in polarity:
  each_polarity['title'] = each_polarity['title'].str.lower()
  each_polarity['text'] = each_polarity['title'].str.lower()

# %%
previous_days = 6
for each_polarity in polarity:
  # Add scaler to first row
  for i in range(0, previous_days):
    name="scaler-"+str(i+1)
    each_polarity.loc[0, name] = each_polarity.loc[0, 'today_scaler']
  # Add scaler to the remaining rows
  for i in range(1, len(each_polarity)):
    for s in range(0, previous_days):
      name="scaler-"+str(s+1)
      if (i-(s+1) >= 0):
        each_polarity.loc[i, name] = each_polarity.loc[i-(s+1), 'today_scaler']
      else:
        each_polarity.loc[i, name] = each_polarity.loc[i-1, 'today_scaler']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.naive_bayes import MultinomialNB

# %%
for each_polarity in polarity:
  each_polarity = each_polarity[['publishedDate', 'symbol', 'indicator', 'Close', 'title', 'text', 'today_scaler', 'scaler-1', 'scaler-2', 'scaler-3', 'scaler-4', 'scaler-5', 'scaler-6']]
  print(each_polarity['symbol'][0])
  test = each_polarity
  train=test[test['publishedDate']<'2020-06-01']
  test=test[test['publishedDate']>'2020-05-31']
  data=train.iloc[:,2:4]
  data.replace("[^a-zA-Z]", " ",regex=True, inplace=True)
  # Join title and text
  headlines = []
  for row in range(0, len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[row, 0:2]))
  #implement TF-IDF
  tfvector=TfidfVectorizer(ngram_range=(2,3))
  train_df=tfvector.fit_transform(headlines)
  # MultinomialNB
  nb=MultinomialNB()
  nb.fit(train_df,train['indicator'])
  # Predict for the Test Dataset
  test_transform= []
  for row in range(0,len(test.index)):
      test_transform.append(' '.join(str(x) for x in test.iloc[row,4:13]))
  test_dataset = tfvector.transform(test_transform)


  predictions = nb.predict(test_dataset)
  matrix=confusion_matrix(test['indicator'],predictions)
  print(matrix)
  score=accuracy_score(test['indicator'],predictions)
  print(score)
  report=classification_report(test['indicator'],predictions)
  print(report)
# Out:
# TSLA
# [[ 0 61]
#  [ 0 89]]
# 0.5933333333333334
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        61
#          1.0       0.59      1.00      0.74        89
#
#     accuracy                           0.59       150
#    macro avg       0.30      0.50      0.37       150
# weighted avg       0.35      0.59      0.44       150
#
# INTC
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[ 0 70]
#  [ 0 80]]
# 0.5333333333333333
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        70
#          1.0       0.53      1.00      0.70        80
#
#     accuracy                           0.53       150
#    macro avg       0.27      0.50      0.35       150
# weighted avg       0.28      0.53      0.37       150
#
# PFE
# [[ 0 81]
#  [ 0 69]]
# 0.46
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        81
#          1.0       0.46      1.00      0.63        69
#
#     accuracy                           0.46       150
#    macro avg       0.23      0.50      0.32       150
# weighted avg       0.21      0.46      0.29       150
#
# SPGI
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[ 0 75]
#  [ 0 75]]
# 0.5
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        75
#          1.0       0.50      1.00      0.67        75
#
#     accuracy                           0.50       150
#    macro avg       0.25      0.50      0.33       150
# weighted avg       0.25      0.50      0.33       150
#
# ADSK
# [[ 0 64]
#  [ 0 86]]
# 0.5733333333333334
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        64
#          1.0       0.57      1.00      0.73        86
#
#     accuracy                           0.57       150
#    macro avg       0.29      0.50      0.36       150
# weighted avg       0.33      0.57      0.42       150
#
# VRTX
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[ 0 73]
#  [ 0 77]]
# 0.5133333333333333
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        73
#          1.0       0.51      1.00      0.68        77
#
#     accuracy                           0.51       150
#    macro avg       0.26      0.50      0.34       150
# weighted avg       0.26      0.51      0.35       150
#
# TWTR
# [[ 0 61]
#  [ 0 89]]
# 0.5933333333333334
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        61
#          1.0       0.59      1.00      0.74        89
#
#     accuracy                           0.59       150
#    macro avg       0.30      0.50      0.37       150
# weighted avg       0.35      0.59      0.44       150
#
# EBAY
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[ 0 72]
#  [ 0 78]]
# 0.52
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        72
#          1.0       0.52      1.00      0.68        78
#
#     accuracy                           0.52       150
#    macro avg       0.26      0.50      0.34       150
# weighted avg       0.27      0.52      0.36       150
#
# GRMN
# [[ 0 70]
#  [ 0 80]]
# 0.5333333333333333
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        70
#          1.0       0.53      1.00      0.70        80
#
#     accuracy                           0.53       150
#    macro avg       0.27      0.50      0.35       150
# weighted avg       0.28      0.53      0.37       150
#
# AAL
# [[79  0]
#  [71  0]]
# 0.5266666666666666
#               precision    recall  f1-score   support
#
#          0.0       0.53      1.00      0.69        79
#          1.0       0.00      0.00      0.00        71
#
#     accuracy                           0.53       150
#    macro avg       0.26      0.50      0.34       150
# weighted avg       0.28      0.53      0.36       150
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test = polarity[0]

# %%
polarity[0]

# %%
train=test[test['publishedDate']<'2020-06-01']
test=test[test['publishedDate']>'2020-05-31']

# %%
data=train.iloc[:,2:4]
data.replace("[^a-zA-Z]", " ",regex=True, inplace=True)

# %%
# Join title and text
headlines = []
for row in range(0, len(data.index)):
  headlines.append(' '.join(str(x) for x in data.iloc[row, 0:2]))

# %%
#headlines

# %%
#implement TF-IDF
tfvector=TfidfVectorizer(ngram_range=(2,3))
train_df=tfvector.fit_transform(headlines)

# %%
train_df

# %%
# MultinomialNB
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()
nb.fit(train_df,train['indicator'])

# %%
test

# %%
# Predict for the Test Dataset
test_transform= []
for row in range(0,len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[row,1:4]))
test_dataset = tfvector.transform(test_transform)

# %%
predictions = nb.predict(test_dataset)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
matrix=confusion_matrix(test['indicator'],predictions)
print(matrix)
score=accuracy_score(test['indicator'],predictions)
print(score)
report=classification_report(test['indicator'],predictions)
print(report)

# %%
print(predictions[2])
# Out:
# 1.0

# %%
test[['title', 'text']].replace("[^a-zA-Z]", " ",regex=True, inplace=True)

# %%
a

# %%
polarity[0]

# %% [markdown]
# # BELOW WAS PAST CODE

# %%
previous_days = 5
for each_polarity in polarity:
  # Add scaler to first row
  for i in range(0, previous_days):
    name="scaler-"+str(i+1)
    each_polarity.loc[0, name] = each_polarity.loc[0, 'today_scaler']
  # Add scaler to the remaining rows
  for i in range(1, len(each_polarity)):
    for s in range(0, previous_days):
      name="scaler-"+str(s+1)
      if (i-(s+1) >= 0):
        each_polarity.loc[i, name] = each_polarity.loc[i-(s+1), 'today_scaler']
      else:
        each_polarity.loc[i, name] = each_polarity.loc[i-1, 'today_scaler']

# %%
polarity[0]

# %% [markdown]
# # Calculate title and text's daily polarity mean respectively

# %%
polarity = []
# Calcuate mean on daily basis
for each_df in df:
  each_title_mean = each_df.groupby('publishedDate', as_index=False)['title_compound'].mean()
  each_text_mean = each_df.groupby('publishedDate', as_index=False)['text_compound'].mean()
  each_polarity = pd.merge(each_title_mean, each_text_mean, on='publishedDate')
  each_polarity['symbol'] = each_df['symbol']
  polarity.append(each_polarity)

# %%
#polarity[0]

# %% [markdown]
# # Merge everyday's closing price with polarity dataframe, but show everyday's closing price

# %%
# Merge everyday's closing price with polarity dataframe
index = 0
for ticker in ALL_TICKERS:
  data = pd.read_csv("./stock_price/compare_previous_day/"+ticker[1:]+".csv")
  data = data[['Date', 'Close']]
  data['publishedDate'] = data['Date']
  data = data[['publishedDate', 'Close']]
  polarity[index] = pd.merge(data, polarity[index], on = 'publishedDate', how = 'left').fillna(0)
  index+=1

# %%
# Fill symbol column for each company
for index, each_polarity in enumerate(polarity):
  each_polarity['symbol'] = ALL_TICKERS[index][1:]

# %%
#polarity[0]

# %% [markdown]
# # Apply MinMax scaler to Close price

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
for each_polarity in polarity:
  close = each_polarity['Close']
  scaler = MinMaxScaler(feature_range=(0,1))
  close = scaler.fit_transform(np.array(close).reshape(-1,1))
  each_polarity['today_scaler'] = close

# %%
#polarity[1]

# %% [markdown]
# # Merge everyday's indicator with poliarity dataframe

# %%
for each_polarity in polarity:
  data = pd.read_csv("./stock_price/compare_previous_day/"+each_polarity.symbol.loc[0]+".csv")
  each_polarity['indicator'] = data['indicator']

# %%
#polarity[0]

# %% [markdown]
# # Add previous 3 day's scaler to each row

# %%
previous_days = 5
for each_polarity in polarity:
  # Add scaler to first row
  for i in range(0, previous_days):
    name="scaler-"+str(i+1)
    each_polarity.loc[0, name] = each_polarity.loc[0, 'today_scaler']
  # Add scaler to the remaining rows
  for i in range(1, len(each_polarity)):
    for s in range(0, previous_days):
      name="scaler-"+str(s+1)
      if (i-(s+1) >= 0):
        each_polarity.loc[i, name] = each_polarity.loc[i-(s+1), 'today_scaler']
      else:
        each_polarity.loc[i, name] = each_polarity.loc[i-1, 'today_scaler']

# %%
polarity[0]

# %% [markdown]
# # Add S&P 500 Index

# %%
sp_df = pd.read_csv("./stock_price/original/S&P500.csv")
def reorder_date(date):
  return date[6:10]+'-'+date[0:5]
sp_df['publishedDate'] = sp_df['Date'].apply(reorder_date)
sp_df = sp_df[['publishedDate', 'Close']]
sp_df = sp_df.iloc[::-1]
sp_df = sp_df.rename(columns= {'Close': "s&p500_close_price"}, inplace=False)
# Convert str to float
sp_df['s&p500_close_price'] = pd.to_numeric(sp_df['s&p500_close_price'], downcast="float")
sp_df

# %%
# Merge with polarity dataframe
for index, ep in enumerate(polarity):
  polarity[index] = pd.merge(ep, sp_df, on="publishedDate")

# %%
polarity[1]

# %% [markdown]
# # Predict the trend using MLPClassifier model

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.utils.testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# %%
@ignore_warnings(category=ConvergenceWarning)
def predict(polarity):
  avg_accuracy = 0
  for each_polarity in polarity:
    y = each_polarity['indicator']
    X = each_polarity.drop(columns=['indicator','publishedDate','symbol'])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    # apply MLPClassifier
    out_date = each_polarity.publishedDate.values
    #rf = RandomForestRegressor(n_estimators=150)
    nn = MLPClassifier(
      hidden_layer_sizes=(90,10),
      random_state=0,
      max_iter=60,
    )
    nn.fit(X_train, y_train)
    #rf.fit(X_train, y_train)
    y_pred = nn.predict(X_test)
    print(accuracy_score(y_test, y_pred))
    avg_accuracy+=accuracy_score(y_test, y_pred)
    #mse = mean_squared_error(y_test, y_pred)
    #corr = np.corrcoef(X_train, y_train, rowvar=False)[-1, :-1]
    #corr = corr.max()
    accuracy = accuracy_score(y_test, y_pred)
    f = open(each_polarity.symbol.iloc[0]+".summary.csv", "w")
    f.write("accuracy\n")
    f.write("{:.2f}\n".format(accuracy))
    f.close()

    f = open(each_polarity.symbol.iloc[0]+".output.csv", "w")
    f.write("date,predicted_indicator\n")
    for i in range(y_pred.shape[0]):
        f.write("{},{}\n".format(out_date[i], y_pred[i]))
    f.close()
  print("AVERAGE ACCURACY: "+str(avg_accuracy/11))

# %%
predict(polarity)
