# %%
import pandas as pd
import numpy as np
import json
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import precision_score, recall_score, accuracy_score, mean_squared_error

# %% [markdown]
# # For each ticker (company), store all news into a dataframe

# %%
# Return one season's financial news dataframe
def season_dataframe(ticker, season):
    with open('./financial_news/'+ticker+str(season), 'r') as ticker_news:
        content  = ticker_news.read()
    records = json.loads(content)
    df = pd.DataFrame(records)
    return df

# %%
# Create dataframe for each ticker, storing its news
ALL_TICKERS = ["$TSLA", "$INTC", "$PFE", "$SPGI", "$ADSK", "$VRTX", "$TWTR", "$EBAY", "$GRMN", "$AAL", "$ANET"]
df = []
for ticker in ALL_TICKERS:
  # Concatenate 8 seasons into one dataframe
  df_temp = pd.DataFrame()
  for i in range(1, 9):
      new_df = season_dataframe(ticker, i)
      df_temp = pd.concat([df_temp, new_df], ignore_index=True)
  df.append(df_temp)

# %% [markdown]
# Usage: df[0] will return $TSLA news from 2019-01-01 to 2020-12-31

# %% [markdown]
# # Calculate Polarity of each news, using nltk.sentiment.vader package

# %%
# Calculate vader
vader = SentimentIntensityAnalyzer()

# Helper function, which calculates the sentiment and returns compund score
def cal_compound(t):
    return vader.polarity_scores(t)["compound"]

# %%
for each_df in df:
  each_df['title_compound'] = each_df['title'].apply(cal_compound)
  each_df['text_compound'] = each_df['text'].apply(cal_compound)

# %% [markdown]
# Convert publishedDate to YYYY-MM-DD

# %%
# Helper function: for the date conversion
def remove_time(publish_date):
  return publish_date[0:10]

# %%
for each_df in df:
  each_df['publishedDate'] = each_df['publishedDate'].apply(remove_time)

# %% [markdown]
# Convert weekend to next Monday

# %%
# Helper function: Convert weekend to next Monday
def moveWeekend(publish_date):
  d = datetime.datetime(int(publish_date[0:4]), int(publish_date[5:7]), int(publish_date[8:10]))
  if (d.weekday() == 5):
    return str(d+datetime.timedelta(days=2))[0:10]
  elif (d.weekday() == 6):
    return str(d+datetime.timedelta(days=1))[0:10]
  else:
    return publish_date

# %%
for each_df in df:
  each_df['publishedDate'] = each_df['publishedDate'].apply(moveWeekend)

# %%
df[0]
# Out:
#      symbol publishedDate                                              title  \
# 0      TSLA    2020-12-31  Tesla to deliver China-made Model Y SUVs this ...
# 1      TSLA    2020-12-31  2020: Several Chinese Stocks Outperformed Thei...
# 2      TSLA    2020-12-31     EV Company News For The Month Of December 2020
# 3      TSLA    2020-12-31  Tesla, Volkswagen, Renault See Strong Share In...
# 4      TSLA    2020-12-31  Tech's top seven companies added $3.4 trillion...
# ...     ...           ...                                                ...
# 5817   TSLA    2019-01-18         Behind Elon Musk's Hiring and Firing Spree
# 5818   TSLA    2019-01-17  Tesla to cut full time workforce by roughly 7%...
# 5819   TSLA    2019-01-07  Cramer: New Tesla factory in Shanghai will wor...
# 5820   TSLA    2019-01-03  Tesla stock drops over missed delivery estimat...
# 5821   TSLA    2019-01-01  Tesla misses Wall Street estimates with 90,700...
#
#                                                   image                  site  \
# 0     https://cdn.snapi.dev/images/v1/5/m/m02d202101...               Reuters
# 1     https://cdn.snapi.dev/images/v1/f/j/catalog-ma...         Seeking Alpha
# 2     https://cdn.snapi.dev/images/v1/l/r/sssik22-c5...         Seeking Alpha
# 3       https://cdn.snapi.dev/images/v1/v/x/s3xy-14.jpg              Benzinga
# 4     https://cdn.snapi.dev/images/v1/s/t/stocks23-1...                  CNBC
# ...                                                 ...                   ...
# 5817  https://cdn.snapi.dev/images/v1/v/i/viwtqd6wkp...  Bloomberg Technology
# 5818  https://cdn.snapi.dev/images/v1/t/8/t8cnbozbfx...       CNBC Television
# 5819  https://cdn.snapi.dev/images/v1/w/g/wgegqwogy8...       CNBC Television
# 5820  https://cdn.snapi.dev/images/v1/b/e/bebskx74-2...          Fox Business
# 5821  https://cdn.snapi.dev/images/v1/p/l/plxkuv4cmd...       CNBC Television
#
#                                                    text  \
# 0     Tesla Inc said on Friday it has started sellin...
# 1     2020: Several Chinese Stocks Outperformed Thei...
# 2     Global electric car sales records for November...
# 3     The European market continues to see strong ad...
# 4     Big Tech got much bigger in 2020, and Tesla jo...
# ...                                                 ...
# 5817  Elon Musk is cutting Tesla Inc.'s workforce by...
# 5818  The Wall Street Journal is reporting that Tesl...
# 5819  CNBC's Jim Cramer discusses his take on the la...
# 5820  “Bulls & Bears” panel discusses how Tesla shar...
# 5821  CNBC's Phil LeBeau reports on Tesla's deliveri...
#
#                                                     url  title_compound  \
# 0     https://www.reuters.com/article/us-tesla-china...          0.0000
# 1     https://seekingalpha.com/article/4396892-2020-...          0.0000
# 2     https://seekingalpha.com/article/4396884-ev-co...          0.0000
# 3     https://www.benzinga.com/news/20/12/18973120/t...          0.6705
# 4     https://www.cnbc.com/2020/12/31/techs-top-seve...          0.4939
# ...                                                 ...             ...
# 5817        https://www.youtube.com/watch?v=ViwTqD6WKpA         -0.3400
# 5818        https://www.youtube.com/watch?v=t8CNBOZBFXc         -0.2732
# 5819        https://www.youtube.com/watch?v=WGEgQWogY8E          0.0000
# 5820        https://www.youtube.com/watch?v=Bebskx74-2Y         -0.5267
# 5821        https://www.youtube.com/watch?v=pLxkuV4cmdI         -0.2263
#
#       text_compound
# 0            0.1027
# 1            0.0000
# 2            0.8402
# 3            0.5106
# 4            0.0000
# ...             ...
# 5817        -0.4404
# 5818         0.0258
# 5819         0.0000
# 5820        -0.1280
# 5821        -0.2960
#
# [5822 rows x 9 columns]

# %% [markdown]
# # Calculate title and text's daily polarity mean respectively

# %%
polarity = []
# Calcuate mean on daily basis
for each_df in df:
  each_title_mean = each_df.groupby('publishedDate', as_index=False)['title_compound'].mean()
  each_text_mean = each_df.groupby('publishedDate', as_index=False)['text_compound'].mean()
  each_polarity = pd.merge(each_title_mean, each_text_mean, on='publishedDate')
  each_polarity['symbol'] = each_df['symbol']
  each_polarity['title'] = each_df['title']
  each_polarity['text'] = each_df['text']
  polarity.append(each_polarity)

# %%
polarity[0]
# Out:
#     publishedDate  title_compound  text_compound symbol  \
# 0      2019-01-01       -0.226300      -0.296000   TSLA
# 1      2019-01-03       -0.526700      -0.128000   TSLA
# 2      2019-01-07        0.000000       0.000000   TSLA
# 3      2019-01-17       -0.273200       0.025800   TSLA
# 4      2019-01-18       -0.340000      -0.440400   TSLA
# ..            ...             ...            ...    ...
# 429    2020-12-25        0.148000       0.509500   TSLA
# 430    2020-12-28        0.081800       0.378638   TSLA
# 431    2020-12-29        0.209004       0.202939   TSLA
# 432    2020-12-30        0.209600       0.323291   TSLA
# 433    2020-12-31        0.191190       0.302485   TSLA
#
#                                                  title  \
# 0    Tesla to deliver China-made Model Y SUVs this ...
# 1    2020: Several Chinese Stocks Outperformed Thei...
# 2       EV Company News For The Month Of December 2020
# 3    Tesla, Volkswagen, Renault See Strong Share In...
# 4    Tech's top seven companies added $3.4 trillion...
# ..                                                 ...
# 429      Tesla to raise another $5bn by selling shares
# 430  LIVE | Apple, Pfizer, Tesla: Jim Cramer's Stoc...
# 431  Tesla Stock Price Receives $2,500 3-Year Targe...
# 432  Tesla files to sell $5B in stock while its sha...
# 433  Tesla Leads EV Race, But These China Tech Upst...
#
#                                                   text
# 0    Tesla Inc said on Friday it has started sellin...
# 1    2020: Several Chinese Stocks Outperformed Thei...
# 2    Global electric car sales records for November...
# 3    The European market continues to see strong ad...
# 4    Big Tech got much bigger in 2020, and Tesla jo...
# ..                                                 ...
# 429  Electric carmaker to join blue-chip S&P 500 in...
# 430  In Tuesday's market breakdown, Jim Cramer talk...
# 431  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...
# 432  Tesla is striking while its share price — and ...
# 433  Chinese electric vehicle stocks Nio, Li Auto, ...
#
# [434 rows x 6 columns]

# %% [markdown]
# # Merge everyday's closing price with polarity dataframe, but show everyday's closing price

# %%
# Merge everyday's closing price with polarity dataframe
index = 0
for ticker in ALL_TICKERS:
  data = pd.read_csv("./stock_price/compare_previous_day/"+ticker[1:]+".csv")
  data = data[['Date', 'Close']]
  data['publishedDate'] = data['Date']
  data = data[['publishedDate', 'Close']]
  polarity[index] = pd.merge(data, polarity[index], on = 'publishedDate', how = 'left').fillna(0)
  index+=1

# %%
# Fill symbol column for each company
for index, each_polarity in enumerate(polarity):
  each_polarity['symbol'] = ALL_TICKERS[index][1:]

# %%
polarity[0]
# Out:
#     publishedDate       Close  title_compound  text_compound symbol  \
# 0      2018-12-31   66.559998        0.000000       0.000000   TSLA
# 1      2019-01-02   62.023998        0.000000       0.000000   TSLA
# 2      2019-01-03   60.071999       -0.526700      -0.128000   TSLA
# 3      2019-01-04   63.537998        0.000000       0.000000   TSLA
# 4      2019-01-07   66.991997        0.000000       0.000000   TSLA
# ..            ...         ...             ...            ...    ...
# 501    2020-12-24  661.770020        0.158990       0.276630   TSLA
# 502    2020-12-28  663.690002        0.081800       0.378638   TSLA
# 503    2020-12-29  665.989990        0.209004       0.202939   TSLA
# 504    2020-12-30  694.780029        0.209600       0.323291   TSLA
# 505    2020-12-31  705.669983        0.191190       0.302485   TSLA
#
#                                                  title  \
# 0                                                    0
# 1                                                    0
# 2    2020: Several Chinese Stocks Outperformed Thei...
# 3                                                    0
# 4       EV Company News For The Month Of December 2020
# ..                                                 ...
# 501  Cramer on Tesla's plans to sell $5 billion in ...
# 502  LIVE | Apple, Pfizer, Tesla: Jim Cramer's Stoc...
# 503  Tesla Stock Price Receives $2,500 3-Year Targe...
# 504  Tesla files to sell $5B in stock while its sha...
# 505  Tesla Leads EV Race, But These China Tech Upst...
#
#                                                   text
# 0                                                    0
# 1                                                    0
# 2    2020: Several Chinese Stocks Outperformed Thei...
# 3                                                    0
# 4    Global electric car sales records for November...
# ..                                                 ...
# 501  Tesla stock was lower Tuesday morning followin...
# 502  In Tuesday's market breakdown, Jim Cramer talk...
# 503  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...
# 504  Tesla is striking while its share price — and ...
# 505  Chinese electric vehicle stocks Nio, Li Auto, ...
#
# [506 rows x 7 columns]

# %% [markdown]
# # Apply MinMax scaler to Close price

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
for each_polarity in polarity:
  close = each_polarity['Close']
  scaler = MinMaxScaler(feature_range=(0,1))
  close = scaler.fit_transform(np.array(close).reshape(-1,1))
  each_polarity['Close_scaler'] = close

# %%
polarity[0]
# Out:
#     publishedDate       Close  title_compound  text_compound symbol  \
# 0      2018-12-31   66.559998        0.000000       0.000000   TSLA
# 1      2019-01-02   62.023998        0.000000       0.000000   TSLA
# 2      2019-01-03   60.071999       -0.526700      -0.128000   TSLA
# 3      2019-01-04   63.537998        0.000000       0.000000   TSLA
# 4      2019-01-07   66.991997        0.000000       0.000000   TSLA
# ..            ...         ...             ...            ...    ...
# 501    2020-12-24  661.770020        0.158990       0.276630   TSLA
# 502    2020-12-28  663.690002        0.081800       0.378638   TSLA
# 503    2020-12-29  665.989990        0.209004       0.202939   TSLA
# 504    2020-12-30  694.780029        0.209600       0.323291   TSLA
# 505    2020-12-31  705.669983        0.191190       0.302485   TSLA
#
#                                                  title  \
# 0                                                    0
# 1                                                    0
# 2    2020: Several Chinese Stocks Outperformed Thei...
# 3                                                    0
# 4       EV Company News For The Month Of December 2020
# ..                                                 ...
# 501  Cramer on Tesla's plans to sell $5 billion in ...
# 502  LIVE | Apple, Pfizer, Tesla: Jim Cramer's Stoc...
# 503  Tesla Stock Price Receives $2,500 3-Year Targe...
# 504  Tesla files to sell $5B in stock while its sha...
# 505  Tesla Leads EV Race, But These China Tech Upst...
#
#                                                   text  Close_scaler
# 0                                                    0      0.045928
# 1                                                    0      0.039157
# 2    2020: Several Chinese Stocks Outperformed Thei...      0.036243
# 3                                                    0      0.041417
# 4    Global electric car sales records for November...      0.046573
# ..                                                 ...           ...
# 501  Tesla stock was lower Tuesday morning followin...      0.934466
# 502  In Tuesday's market breakdown, Jim Cramer talk...      0.937332
# 503  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...      0.940765
# 504  Tesla is striking while its share price — and ...      0.983743
# 505  Chinese electric vehicle stocks Nio, Li Auto, ...      1.000000
#
# [506 rows x 8 columns]

# %% [markdown]
# # Merge everyday's indicator with poliarity dataframe

# %%
for each_polarity in polarity:
  data = pd.read_csv("./stock_price/compare_previous_day/"+each_polarity.symbol.loc[0]+".csv")
  each_polarity['indicator'] = data['indicator']

# %%
polarity[0]
# Out:
#     publishedDate       Close  title_compound  text_compound symbol  \
# 0      2018-12-31   66.559998        0.000000       0.000000   TSLA
# 1      2019-01-02   62.023998        0.000000       0.000000   TSLA
# 2      2019-01-03   60.071999       -0.526700      -0.128000   TSLA
# 3      2019-01-04   63.537998        0.000000       0.000000   TSLA
# 4      2019-01-07   66.991997        0.000000       0.000000   TSLA
# ..            ...         ...             ...            ...    ...
# 501    2020-12-24  661.770020        0.158990       0.276630   TSLA
# 502    2020-12-28  663.690002        0.081800       0.378638   TSLA
# 503    2020-12-29  665.989990        0.209004       0.202939   TSLA
# 504    2020-12-30  694.780029        0.209600       0.323291   TSLA
# 505    2020-12-31  705.669983        0.191190       0.302485   TSLA
#
#                                                  title  \
# 0                                                    0
# 1                                                    0
# 2    2020: Several Chinese Stocks Outperformed Thei...
# 3                                                    0
# 4       EV Company News For The Month Of December 2020
# ..                                                 ...
# 501  Cramer on Tesla's plans to sell $5 billion in ...
# 502  LIVE | Apple, Pfizer, Tesla: Jim Cramer's Stoc...
# 503  Tesla Stock Price Receives $2,500 3-Year Targe...
# 504  Tesla files to sell $5B in stock while its sha...
# 505  Tesla Leads EV Race, But These China Tech Upst...
#
#                                                   text  Close_scaler  \
# 0                                                    0      0.045928
# 1                                                    0      0.039157
# 2    2020: Several Chinese Stocks Outperformed Thei...      0.036243
# 3                                                    0      0.041417
# 4    Global electric car sales records for November...      0.046573
# ..                                                 ...           ...
# 501  Tesla stock was lower Tuesday morning followin...      0.934466
# 502  In Tuesday's market breakdown, Jim Cramer talk...      0.937332
# 503  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...      0.940765
# 504  Tesla is striking while its share price — and ...      0.983743
# 505  Chinese electric vehicle stocks Nio, Li Auto, ...      1.000000
#
#      indicator
# 0          0.0
# 1          0.0
# 2          0.0
# 3          1.0
# 4          1.0
# ..         ...
# 501        1.0
# 502        1.0
# 503        1.0
# 504        1.0
# 505        1.0
#
# [506 rows x 9 columns]

# %% [markdown]
# # Add previous 7 day's scaler to each row

# %%
for each_polarity in polarity:
  # Add scaler to first row
  for i in range(0, 6):
    name="scaler-"+str(i+1)
    each_polarity.loc[0, name] = each_polarity.loc[0, 'Close_scaler']
  # Add scaler to the remaining rows
  for i in range(1, len(each_polarity)):
    for s in range(0, 6):
      name="scaler-"+str(s+1)
      if (i-(s+1) >= 0):
        each_polarity.loc[i, name] = each_polarity.loc[i-(s+1), 'Close_scaler']
      else:
        each_polarity.loc[i, name] = each_polarity.loc[i-1, 'Close_scaler']

# %%
polarity[0]
# Out:
#     publishedDate       Close  title_compound  text_compound symbol  \
# 0      2018-12-31   66.559998        0.000000       0.000000   TSLA
# 1      2019-01-02   62.023998        0.000000       0.000000   TSLA
# 2      2019-01-03   60.071999       -0.526700      -0.128000   TSLA
# 3      2019-01-04   63.537998        0.000000       0.000000   TSLA
# 4      2019-01-07   66.991997        0.000000       0.000000   TSLA
# ..            ...         ...             ...            ...    ...
# 501    2020-12-24  661.770020        0.158990       0.276630   TSLA
# 502    2020-12-28  663.690002        0.081800       0.378638   TSLA
# 503    2020-12-29  665.989990        0.209004       0.202939   TSLA
# 504    2020-12-30  694.780029        0.209600       0.323291   TSLA
# 505    2020-12-31  705.669983        0.191190       0.302485   TSLA
#
#                                                  title  \
# 0                                                    0
# 1                                                    0
# 2    2020: Several Chinese Stocks Outperformed Thei...
# 3                                                    0
# 4       EV Company News For The Month Of December 2020
# ..                                                 ...
# 501  Cramer on Tesla's plans to sell $5 billion in ...
# 502  LIVE | Apple, Pfizer, Tesla: Jim Cramer's Stoc...
# 503  Tesla Stock Price Receives $2,500 3-Year Targe...
# 504  Tesla files to sell $5B in stock while its sha...
# 505  Tesla Leads EV Race, But These China Tech Upst...
#
#                                                   text  Close_scaler  \
# 0                                                    0      0.045928
# 1                                                    0      0.039157
# 2    2020: Several Chinese Stocks Outperformed Thei...      0.036243
# 3                                                    0      0.041417
# 4    Global electric car sales records for November...      0.046573
# ..                                                 ...           ...
# 501  Tesla stock was lower Tuesday morning followin...      0.934466
# 502  In Tuesday's market breakdown, Jim Cramer talk...      0.937332
# 503  Shares of Tesla Inc (NASDAQ: TSLA) have receiv...      0.940765
# 504  Tesla is striking while its share price — and ...      0.983743
# 505  Chinese electric vehicle stocks Nio, Li Auto, ...      1.000000
#
#      indicator  scaler-1  scaler-2  scaler-3  scaler-4  scaler-5  scaler-6
# 0          0.0  0.045928  0.045928  0.045928  0.045928  0.045928  0.045928
# 1          0.0  0.045928  0.045928  0.045928  0.045928  0.045928  0.045928
# 2          0.0  0.039157  0.045928  0.039157  0.039157  0.039157  0.039157
# 3          1.0  0.036243  0.039157  0.045928  0.036243  0.036243  0.036243
# 4          1.0  0.041417  0.036243  0.039157  0.045928  0.041417  0.041417
# ..         ...       ...       ...       ...       ...       ...       ...
# 501        1.0  0.910894  0.902475  0.916686  0.984072  0.925703  0.876246
# 502        1.0  0.934466  0.910894  0.902475  0.916686  0.984072  0.925703
# 503        1.0  0.937332  0.934466  0.910894  0.902475  0.916686  0.984072
# 504        1.0  0.940765  0.937332  0.934466  0.910894  0.902475  0.916686
# 505        1.0  0.983743  0.940765  0.937332  0.934466  0.910894  0.902475
#
# [506 rows x 15 columns]

# %% [markdown]
# # Add S&P 500 Index

# %%
sp_df = pd.read_csv("./stock_price/original/S&P500.csv")
def reorder_date(date):
  return date[6:10]+'-'+date[0:5]
sp_df['publishedDate'] = sp_df['Date'].apply(reorder_date)
sp_df = sp_df[['publishedDate', 'Close']]
sp_df = sp_df.iloc[::-1]
sp_df = sp_df.rename(columns= {'Close': "s&p500_close_price"}, inplace=False)
# Convert str to float
sp_df['s&p500_close_price'] = pd.to_numeric(sp_df['s&p500_close_price'], downcast="float")
sp_df
# Out:
#     publishedDate  s&p500_close_price
# 755    2018-01-02         2695.810059
# 754    2018-01-03         2713.060059
# 753    2018-01-04         2723.989990
# 752    2018-01-05         2743.149902
# 751    2018-01-08         2747.709961
# ..            ...                 ...
# 4      2020-12-24         3703.060059
# 3      2020-12-28         3735.360107
# 2      2020-12-29         3727.040039
# 1      2020-12-30         3732.040039
# 0      2020-12-31         3756.070068
#
# [756 rows x 2 columns]

# %%
# Merge with polarity dataframe
for index, ep in enumerate(polarity):
  polarity[index] = pd.merge(ep, sp_df, on="publishedDate")

# %%
# a = polarity[1]
# a.drop(columns=['scaler-7', 'scaler-6']).tail(50)

# %%
polarity[1].tail(50)
# Out:
#     publishedDate      Close  title_compound  text_compound symbol  \
# 456    2020-10-21  53.500000        0.179068       0.232605   INTC
# 457    2020-10-22  53.900002        0.026352       0.145190   INTC
# 458    2020-10-23  48.200001       -0.015557      -0.015129   INTC
# 459    2020-10-26  46.720001       -0.165880       0.258340   INTC
# 460    2020-10-27  45.639999       -0.186500       0.204133   INTC
# 461    2020-10-28  44.250000       -0.010150       0.145175   INTC
# 462    2020-10-29  44.110001        0.210612       0.325688   INTC
# 463    2020-10-30  44.279999        0.421500       0.000000   INTC
# 464    2020-11-02  44.459999        0.022540       0.123840   INTC
# 465    2020-11-03  44.849998        0.000000       0.000000   INTC
# 466    2020-11-04  45.700001        0.000000       0.590600   INTC
# 467    2020-11-05  45.680000        0.312450       0.000000   INTC
# 468    2020-11-06  45.389999        0.000000       0.000000   INTC
# 469    2020-11-09  45.599998        0.220200       0.636400   INTC
# 470    2020-11-10  45.439999        0.000000       0.051600   INTC
# 471    2020-11-11  46.349998        0.192250      -0.017833   INTC
# 472    2020-11-12  44.950001        0.000000       0.493900   INTC
# 473    2020-11-13  45.459999       -0.120075       0.313350   INTC
# 474    2020-11-16  46.189999        0.032180      -0.162540   INTC
# 475    2020-11-17  45.529999        0.244160       0.235260   INTC
# 476    2020-11-18  45.060001        0.148000       0.578200   INTC
# 477    2020-11-19  45.619999        0.032175      -0.177325   INTC
# 478    2020-11-20  45.389999        0.000000       0.204133   INTC
# 479    2020-11-23  46.060001       -0.074083       0.082300   INTC
# 480    2020-11-24  47.009998        0.000000       0.000000   INTC
# 481    2020-11-25  47.049999        0.389175       0.229350   INTC
# 482    2020-11-27  47.450001        0.000000       0.000000   INTC
# 483    2020-11-30  48.349998        0.340400       0.861300   INTC
# 484    2020-12-01  49.560001        0.240700       0.398350   INTC
# 485    2020-12-02  49.900002        0.115425       0.331600   INTC
# 486    2020-12-03  50.990002        0.040983       0.011267   INTC
# 487    2020-12-04  51.990002        0.200950       0.000000   INTC
# 488    2020-12-07  50.200001        0.004664       0.172871   INTC
# 489    2020-12-08  50.689999        0.044940       0.535400   INTC
# 487        1.0  0.301080  0.257497  0.243902  0.195522  0.159536  0.143543
# 488        0.0  0.341064  0.301080  0.257497  0.243902  0.195522  0.159536
# 489        1.0  0.269492  0.341064  0.301080  0.257497  0.243902  0.195522
# 490        0.0  0.289084  0.269492  0.341064  0.301080  0.257497  0.243902
# 491        1.0  0.264294  0.289084  0.269492  0.341064  0.301080  0.257497
# 492        0.0  0.271891  0.264294  0.289084  0.269492  0.341064  0.301080
# 493        1.0  0.250700  0.271891  0.264294  0.289084  0.269492  0.341064
# 494        1.0  0.280288  0.250700  0.271891  0.264294  0.289084  0.269492
# 495        1.0  0.288285  0.280288  0.250700  0.271891  0.264294  0.289084
# 496        0.0  0.306277  0.288285  0.280288  0.250700  0.271891  0.264294
# 497        0.0  0.287485  0.306277  0.288285  0.280288  0.250700  0.271891
# 498        0.0  0.159936  0.287485  0.306277  0.288285  0.280288  0.250700
# 499        0.0  0.115954  0.159936  0.287485  0.306277  0.288285  0.280288
# 500        1.0  0.108357  0.115954  0.159936  0.287485  0.306277  0.288285
# 501        1.0  0.124350  0.108357  0.115954  0.159936  0.287485  0.306277
# 502        0.0  0.144342  0.124350  0.108357  0.115954  0.159936  0.287485
# 503        1.0  0.144342  0.144342  0.124350  0.108357  0.115954  0.159936
# 504        0.0  0.237105  0.144342  0.144342  0.124350  0.108357  0.115954
# 505        1.0  0.211515  0.237105  0.144342  0.144342  0.124350  0.108357
#
#      s&p500_close_price
# 456         3435.560059
# 457         3453.489990
# 458         3465.389893
# 459         3400.969971
# 460         3390.679932
# 461         3271.030029
# 462         3310.110107
# 463         3269.959961
# 464         3310.239990
# 465         3369.159912
# 466         3443.439941
# 467         3510.449951
# 468         3509.439941
# 469         3550.500000
# 470         3545.530029
# 471         3572.659912
# 472         3537.010010
# 473         3585.149902
# 474         3626.909912
# 475         3609.530029
# 476         3567.790039
# 477         3581.870117
# 478         3557.540039
# 479         3577.590088
# 480         3635.409912
# 481         3629.649902
# 482         3638.350098
# 483         3621.629883
# 484         3662.449951
# 485         3669.010010
# 486         3666.719971
# 487         3699.120117
# 488         3691.959961
# 489         3702.250000
# 490         3672.820068
# 491         3668.100098
# 492         3663.459961
# 493         3647.489990
# 494         3694.620117
# 495         3701.169922
# 496         3722.479980
# 497         3709.409912
# 498         3694.919922
# 499         3687.260010
# 500         3690.010010
# 501         3703.060059
# 502         3735.360107
# 503         3727.040039
# 504         3732.040039
# 505         3756.070068

# %% [markdown]
# # Predict the trend using Passive Aggressive Classifier model

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.utils.testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
# Out:
# /Users/vincent/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
@ignore_warnings(category=ConvergenceWarning)
def predict(polarity):
  avg_accuracy = 0
  for each_polarity in polarity:
    y = each_polarity['indicator']
    X = each_polarity.drop(columns=['indicator', 'publishedDate', 'symbol', 'title', 'text'])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0, shuffle=False)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    # apply passive aggressive classifier
    out_date = each_polarity.publishedDate.values
    nn = PassiveAggressiveClassifier()

    nn.fit(X_train, y_train)
    #rf.fit(X_train, y_train)
    y_pred = nn.predict(X_test)
    print(accuracy_score(y_test, y_pred))
    avg_accuracy+=accuracy_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    f = open(each_polarity.symbol.iloc[0]+".summaryRandomForest.csv", "w")
    f.write("accuracy\n")
    f.write("{:.2f}\n".format(accuracy))
    f.close()

    f = open(each_polarity.symbol.iloc[0]+".outputRandomForest.csv", "w")
    f.write("date,predicted_indicator\n")
    dd = 338
    for i in range(y_pred.shape[0]):
      f.write("{},{}\n".format(out_date[dd], y_pred[i]))
      dd+=1
    f.close()
  print("AVERAGE ACCURACY: "+str(avg_accuracy/11))

# %%
# # split train and test data in consecutive period
# @ignore_warnings(category=ConvergenceWarning)
# def predict_test(polarity):
#   avg_accuracy = 0
#   for each_polarity in polarity:
#     y = each_polarity['indicator']
#     X = each_polarity.drop(columns=['indicator', 'symbol', 'title', 'text'])
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0, shuffle=False)
#     # print(len(X_test))
#     # print(len(X_train))
#     print(X_test)
#     # scaler = StandardScaler()
#     # scaler.fit(X_train)
#     # X_train = scaler.transform(X_train)
#     # X_test = scaler.transform(X_test)

#     # # apply Random Forest Classifier
#     # """ out_date = each_polarity.publishedDate.values
#     # nn = RandomForestClassifier(n_estimators=200,criterion='entropy') """

#     # # apply passive aggressive classifier
#     # out_date = each_polarity.publishedDate.values
#     # nn = PassiveAggressiveClassifier()

#     # nn.fit(X_train, y_train)
#     # #rf.fit(X_train, y_train)
#     # y_pred = nn.predict(X_test)
#     # print(accuracy_score(y_test, y_pred))
#     # avg_accuracy+=accuracy_score(y_test, y_pred)
#     # accuracy = accuracy_score(y_test, y_pred)
#     # f = open(each_polarity.symbol.iloc[0]+".summaryRandomForest.csv", "w")
#     # f.write("accuracy\n")
#     # f.write("{:.2f}\n".format(accuracy))
#     # f.close()

#     # f = open(each_polarity.symbol.iloc[0]+".outputRandomForest.csv", "w")
#     # f.write("date,predicted_indicator\n")
#     # for i in range(y_pred.shape[0]):
#     #   f.write("{},{}\n".format(out_date[i], y_pred[i]))
#     # f.close()
#     break
#   print("AVERAGE ACCURACY: "+str(avg_accuracy/11))

# %%
# len(polarity)

# %%
# """ i = 0
# for each_polarity in polarity:
#     each_polarity = each_polarity.drop('title', axis=1)
#     each_polarity = each_polarity.drop('text', axis=1)
#     polarity[i] = each_polarity
#     i+=1 """

# i = 0
# for each_polarity in polarity:
#     each_polarity.fillna(' ')
#     polarity[i] = each_polarity
#     i+=1

# %%
# i=0
# for each_polarity in polarity:
#     each_polarity = each_polarity.drop('scaler-7', axis=1)
#     polarity[i] = each_polarity
#     i+=1

# %%
# polarity[0]

# %%
# polarity[1].indicator.to_csv('testesttest.txt', index=False)

# %%
# predict_test(polarity)

# %%
predict(polarity)
# Out:
# 0.6766467065868264
# 0.8802395209580839
# 0.8802395209580839
# 0.7365269461077845
# 0.7904191616766467
# 0.844311377245509
# 0.9101796407185628
# 0.8203592814371258
# 0.8502994011976048
# 0.5449101796407185
# 0.9461077844311377
# AVERAGE ACCURACY: 0.8072945019052805
