# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {'Closing Price':[192.169998, 197.195999, 191.947998, 195.844998, 196.844998]}
df = pd.DataFrame(data, index=['2020-06-24', '2020-06-25', "2020-06-26", "2020-06-27", "2020-06-28"])

data1 = {'Closing Price':[196.844998]}
df1 = pd.DataFrame(data1, index=["2020-06-28"])

# %%
plt.plot(df, 'r')

# %%
plt.plot(df, 'g')

# %%
# Below for Pfizer testing
data = {'Closing Price':[33.377609, 32.836811, 33.083492, 33.28273, 32.28273]}
df = pd.DataFrame(data, index=['2019-08-19', '2019-08-20', "2019-08-21", "2019-08-22", "2019-08-23"])

# %%
plt.plot(df, 'r')
